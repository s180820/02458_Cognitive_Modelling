# %%
# calculate the perceived stimulus intensity, Ip, for physical intensities 
# Is = 1, 2, . . . , 10 using Steven’s law.

import numpy as np
import matplotlib.pyplot as plt

# define the function
def Stevens(Is,a):
    return 10*Is**(a)

# define the range of Is
Is = np.arange(1,11)

# calculate the perceived stimulus intensity
Ip = Stevens(Is,0.33)

# plot the results
plt.plot(Is, Ip, 'o-')
plt.xlabel('Physical Intensity')
plt.ylabel('Perceived Intensity')
plt.title('Steven\'s Law')
plt.show()

# %%
# This simulates an observer that rates the perceived intensity according 
# to Stevens’ law. Fit Fechner’s law to the simulated data. 
# Note that Fechner’s law is linear with respect to Is.

# define the function
def fechner(Is,c, I0):
    return (1/c)*np.log(Is/I0)

from scipy.optimize import curve_fit

param, cov = curve_fit(fechner, Is, Ip)
fit_fech = fechner(Is, param[0], param[1])

print("Optimal Weber fraction", param[0])
print("I0:", param[1])

# plot the results
plt.plot(Is, Ip, 'o-',label='Steven\'s Law')
plt.plot(Is, fit_fech, 'o-', label='Fitted Fechner\'s Law (with a=0.33)')
plt.xlabel('Physical Intensity')
plt.ylabel('Perceived Intensity')
#plt.title('Fitted Fechner\'s Law (with a=0.33)')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_386/3887149710.py:7: RuntimeWarning: invalid value encountered in log
#   return (1/c)*np.log(Is/I0)
# Optimal Weber fraction 0.19980887992684862
# I0: 0.155595193327167

# %%
Ip = Stevens(Is, 3.3)

param, cov = curve_fit(fechner, Is, Ip, maxfev=5000)
fit_fech = fechner(Is, param[0], param[1])

print("Optimal Weber fraction:", param[0])
print("I0:", param[1])
# plot the results
plt.plot(Is, Ip, 'o-',label='Steven\'s Law')
plt.plot(Is, fit_fech, 'o-', label='Fitted Fechner\'s Law (with a=3.3)')
plt.xlabel('Physical Intensity')
plt.ylabel('Perceived Intensity')
#plt.title('Fitted Fechner\'s Law (with a=3.3)')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_386/3887149710.py:7: RuntimeWarning: invalid value encountered in log
#   return (1/c)*np.log(Is/I0)
# Optimal Weber fraction: 0.00014030008966316076
# I0: 2.0375854567632015

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=0153691c-15dd-4c7c-b94c-78660e6bf471' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
